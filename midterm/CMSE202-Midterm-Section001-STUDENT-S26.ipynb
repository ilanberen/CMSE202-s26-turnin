# %% [markdown]
# # CMSE 202 Midterm (Section 001 - Spring 2026)
#
# The goal of this midterm is to give you the opportunity to test out some of the skills that you've developed thus far this semester.
#
# The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time. If you have any questions during the exam, you may ask the instructor, the TA, or the LA privately: simply raise your hand and one of us will come over to you.
#
# **Permitted Resources:**
# You may use files stored locally on your own computer or on the JupyterHub server in engineering (https://jupyterhub.egr.msu.edu/). This includes any Jupyter Notebook files, code samples, or study materials that you personally created while preparing for this exam.
#
# **Prohibited Resources:**
# In accordance with the course’s Generative AI Policy, this is a closed-internet exam. You are not permitted to access any online or cloud-based resources during the exam . This restriction includes (but is not limited to):
#
# - Web searches (e.g., Google, Bing)
# - Generative AI tools or coding assistants (e.g., ChatGPT, GitHub Copilot)
# - Online forums or documentation (e.g., Stack Overflow)
# - Any other websites or shared repositories
#
# Accessing any of these resources or using an internet-enabled coding tool during the exam will result in a score of zero.  The only online interaction you are allowed is with your own github.com repositories, specific documentation links supplied directly in the exam, and through command line downloading of needed files and packages.
#
# **Communication Restrictions:**
# All person-to-person communication tools and collaboration platforms are strictly prohibited. You may not access:
#
# - Email or chat software (e.g., Slack, Discord, Teams)
# - Shared storage or editing tools (e.g., Google Drive, Google Docs, OneDrive)
#
# Any attempt to communicate or share information during the exam will be treated as a violation of academic integrity and may also result in a score of zero.
#
# **Academic Integrity Reminder:**
# Please keep your focus on your own screen. Due to limited space, students may be seated close together—so it is essential to maintain exam integrity. You must also keep your screen brightness high enough for instructors to clearly see your activity during the exam. This is your opportunity to demonstrate your individual skills and understanding. Any suspicious or inappropriate behavior observed by the instructors may result in a disciplinary action and a zero on the exam.

# %% [markdown]
# ---
# ## Part 0: Academic integrity statement
#
# Read the following statement and edit the markdown text to put your name in the statement. This is your commitment to doing your own authentic work on this exam.

# %% [markdown]
# > I, Ilan Berenfeld, affirm that this exam represents my own authetic work, without the use of any unpermitted aids or generative AIs or person-to-person communication. I understand that this exam an an opportunity to showcase my own progress in developing and improving my computational skills and have done my best to demonstrate those skills.

# %% [markdown]
# ## Part 1: Add to your Git repository to track your progress on your exam (7 points total)
#
# Before you get to far along in the exam, you're going to add it to the `cmse202-s26-turnin` repository you created in class (or in Homework 1) so that you can track your progress on the exam and preserve the final version that you turn in. In order to do this you need to
#
# 1. Navigate to your `cmse202-s26-turnin` repository and create a new directory called `midterm`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 3. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" respository (you should have done this in the previous homework assignment).
#
# **Important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the noteobok, **none of your changes will be tracked**!
#
# The file should now show up on your GitHub account in the `cmse202-s26-turnin` repository inside the `midterm` directory you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. It can be good to get into a habit of committing your changes any time you make a significant modification.
#
# **Github Issues**: If you encounter merge conflicts or other git issues that can't be fixed in the time of the exam, include the git code in the notebook that would work to complete the task. If the code you include is correct, you will get full points even if the commits don't get pushed to Github.

# %% [markdown]
# &#9989; **Question 1.1 Put all the Git commands you used to add your midterm folder and file to your GitHub repository (1 point)**:

# %% [markdown]
# &#9989; **Do this**:
# ```
# Put the commands you used here (Do Not Delete the ```)
# mkdir midterm
# git add CMSE202-Midterm-Section001-STUDENT-S26.ipynb
# git commit -m 'exam'
# git push origin main
# ```

# %% [markdown]
# &#9989; **Question 1.2 Put the code the instructor will need to clone your repository here (1 point)**:

# %%
### Put your code here:
# !git clone CMSE202-Midterm-Section001-STUDENT-S26.ipynb

# %% [markdown]
# &#9989; **Question 1.3 How can you tell if your git repository is properly set up and tracking changes? What command would you use to check this? (there could be multiple answers) (1 point)**:
# you can use !git log

# %% [markdown]
# &#9989; **Do this**:
# ```
# Put the command line commands here (Do Not Delete the ```)
# !git log
# ```

# %% [markdown]
# &#9989; **Question 1.4 (4 points)**: After completing each of Part 2, Part 3, Part 4, and Part 5 below, save your notebook, commit the changes to your Git repository using a descriptive commit message, and push the changes to GitHub. Note that there are large &#128721; **STOP** signs reminding you to do this after each part.

# %% [markdown]
# ## Part 2: Downloading and analyzing unfamiliar data (13 points)
#
# For this part of the exam, you're to download and analyze a dataset that you've likely not looked at before. You'll perform some simple, exploratorary analysis and create basic visualizations.

# %% [markdown]
# In particular, you're going to be working with a dataset that contains data on all nuclear explosions between 1945 and 1998. The data are from `N.-O. Bergkvist and R. Ferm, Nuclear Explosions 1945–1998, Swedish Defence Research Establishment/SIPRI, Stockholm, July 2000`.
#
# Download the file from
#
# `https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S22-data/main/code_samples/nuclear-explosion-data.csv `

# %% [markdown]
# &#9989; **Question 2.1 (1 point)**: **Do this now:** Save this file in the same directory as your notebook so you can load it directly.
#
# **Then, in the cell below, put the command or commands you used to download the files. If you did not use a command line tool to download the files, write down a command that *would* have fetched the files.**

# %% [markdown]
# ```
# Put the command(s) you used for downloading the data files here!
#
# ```

# %%
# !curl -o nuclear-explosion-data.csv https://raw.githubusercontent.com/msu-cmse-courses/cmse202-S22-data/main/code_samples/nuclear-explosion-data.csv
# Out:
# curl: (2) no URL specified
# curl: try 'curl --help' or 'curl --manual' for more information

# %% [markdown]
# &#9989; **Question 2.2 (2 points)**: To get started, **read in the `nuclear-explosion-data.csv` dataset** and then display the first 10 rows of the data using **Pandas**.
#
# **Reminder:** You can access help for python packages and methods inside Jupyter Notebooks using the `help()` function--This is an allowable use for this exam. For example, you can run `help(pandas)` to get help on the pandas package. And, you can run `help(pandas.my_favorite_example_method)` to get help on the `my_favorite_example_method` method in pandas (which doesn't exist). You can also use the `dir()` command to find functions in a package if you do not remember which functions are available (example: `dir(pd)`)

# %%
# put your code here
import pandas as pd
df=pd.read_csv('nuclear-explosion-data.csv')
df.head()
# Out:
#        date      time     id country      region source    lat    long   mb  \
# 0  19450716  123000.0  45001     USA  ALAMOGORDO    DOE  32.54 -105.57  0.0
# 1  19450805  231500.0  45002     USA   HIROSHIMA    DOE  34.23  132.27  0.0
# 2  19450809   15800.0  45003     USA    NAGASAKI    DOE  32.45  129.52  0.0
# 3  19460630  220100.0  46001     USA      BIKINI    DOE  11.35  165.20  0.0
# 4  19460724  213500.0  46002     USA      BIKINI    DOE  11.35  165.20  0.0
#
#     Ms  depth  yield_lower  yield_upper purpose       name     type
# 0  0.0  -0.10         21.0         21.0      WR    TRINITY    TOWER
# 1  0.0  -0.60         15.0         15.0  COMBAT  LITTLEBOY  AIRDROP
# 2  0.0  -0.60         21.0         21.0  COMBAT     FATMAN  AIRDROP
# 3  0.0  -0.20         21.0         21.0      WE       ABLE  AIRDROP
# 4  0.0   0.03         21.0         21.0      WE      BAKER       UW

# %%
# Run this cell to clean the data and convert the date column to a datetime object.
# Change the `df`` to the name of your dataframe. 
df["date"] = pd.to_datetime(df["date"], format = "%Y%m%d", errors='coerce')
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[153], line 3
#       1 # Run this cell to clean the data and convert the date column to a datetime object.
#       2 # Change the `df`` to the name of your dataframe.
# ----> 3 updated_df["date"] = pd.to_datetime(df["date"], format = "%Y%m%d", errors='coerce')
#       4 updated_df.head()
#
# NameError: name 'updated_df' is not defined

# %% [markdown]
# &#9989; **Question 2.3 (3 points)**: Use built-in Pandas functions to answer the following questions about the data:
#
# 1. How many unique countries have exploded nuclear weapons?
# 2. What are all of the countries that have exploded nuclear weapons according to this dataset?
# 3. How many explosions did the USA perform?

# %%
# Put your code here
df['country'].value_counts()
# Out:
# country
# USA         1032
# USSR         714
# FRANCE       210
# UK            45
# CHINA         45
# INDIA          3
# PAKISTAN       2
# Name: count, dtype: int64

# %% [markdown]
# **<font size=+3>&#9998;</font> Do This**: Put your written answers to these questions here:
#
# 1. There are 7 countries that have exploded nuclear weapons
#
# 2. USA, USSR, France, UK, China, India and Pakistan
#
# 3. The US performed 1032 explosions

# %% [markdown]
# &#9989; **Question 2.4 (5 points)**: Using `seaborn` and the nuclear data make a histogram (You are allowed to access the documentation for seaborn for this problem here: [_Hint_](https://seaborn.pydata.org/examples/index.html) ) :
#
# 1. with the `date` as the `x` axis
#
# 2. set the `bins` option equal to 45
#
# 3. set the `hue` option equal to `country`.
#
# 4. Label the axes and give the plot a title.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")
nuc=sns.displot(x=df['date'],y=df['country'],hue=df['country'],bins=45)
nuc.set_titles(template='")
_ = plt.xticks(rotation = 40) # This line rotates the ticks of the x-axis so that they are easy to read.

# %% [markdown]
# &#9989; **Question 2.5 (2 points)**: Looking at the above output (or other analysis of the data), answer the following questions:
#
# 1. What country used nuclear weapons in 1960?
# 2. What country was the last to use nuclear weapons? Use some code to verify your answer.

# %% [markdown]
# **<font size=+3>&#9998;</font> Do This**: *Record your answers here.*
# France used in 1960
# Pakistan was the last country to use nuclear weapons

# %%
# put your code here
df.sort_values('date')
# Out:
#           date      time     id   country      region source    lat    long  \
# 0     19450716  123000.0  45001       USA  ALAMOGORDO    DOE  32.54 -105.57
# 1     19450805  231500.0  45002       USA   HIROSHIMA    DOE  34.23  132.27
# 2     19450809   15800.0  45003       USA    NAGASAKI    DOE  32.45  129.52
# 3     19460630  220100.0  46001       USA      BIKINI    DOE  11.35  165.20
# 4     19460724  213500.0  46002       USA      BIKINI    DOE  11.35  165.20
# ...        ...       ...    ...       ...         ...    ...    ...     ...
# 2046  19960729   14859.1  96003     CHINA     LOP NOR    HFS  41.69   88.35
# 2047  19980511  101344.0  98001     INDIA     POKHRAN    HFS  27.07   71.70
# 2048  19980513   65100.0  98003     INDIA     POKHRAN    NRD  27.07   71.70
# 2049  19980528  101617.6  98004  PAKISTAN      CHAGAI    HFS  28.90   64.89
# 2050  19980530   65457.1  98005  PAKISTAN      KHARAN    HFS  28.49   63.78
#
# ...

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 3: Working with a new Python package (7 points)

# %% [markdown]
# In this part of the exam, you will install a Python package that you probably have not used before, and use it to perform a simple task. Specifically, you will use a package called `colorama` to add color to print statements in this Jupyter Notebook.  Documentation on `colorama` is available at https://pypi.org/project/colorama/ (You are allowed to visit all of the pages on this website (and only this website) to learn about this package).

# %% [markdown]
# &#9989; **Question 3.1 (1 points)**: The `colorama` package is probably not already installed on your machine. However, you should be able to install the package in the same way we have used previously to install Python packages.
#
# **Do this**: Install the `colorama` Python package.
#
# What command did you use to install `colorama`? **Include this command in the cell below.**

# %%
# Put your code here
# !pip install colorama
# Out:
# /usr/bin/bash: line 1: pip: command not found

# %% [markdown]
# Once `colorama` is installed, running the following cell should not result in an error message. **You might need to restart your Jupyter kernel after installing the package for this to work.** (Once everything works, it should give you no output at all.)

# %%
# Running this cell should just work and not yield any output if colorama is installed and available
from colorama import Fore

# %% [markdown]
# Using the `colorama` package, do the following simple tasks. Each task should only require a very short amount of code, and the documentation should cover how to do it.
#
# &#9989; **Question 3.2 (1 point)**: Using the `colorama` package, print your name in blue text.

# %%
# Put your code for Question 3.2.1 here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 2
#       1 # Put your code for Question 3.2.1 here
# ----> 2 Fore('I')
#
# TypeError: 'AnsiFore' object is not callable

# %% [markdown]
# &#9989; **Question 3.3 (1 point)**: Print your name with black text on a yellow background.

# %%
# Put your code for Question 3.2.2 here

# %% [markdown]
# &#9989; **Question 3.3 (4 points)**: Using the following defined dataframe, write code to display the 4th joke with
#
# 1. person 1 text in blue text
# 2. the recipient of joke, person 2, responses in red text.
#
# Your answer should be generalizable to any joke in the dataframe, so it should work if I change the index from the 4th joke to something else.  **The answer should look something like this**:
#
# <img width=100px align="left" src="https://raw.githubusercontent.com/msu-cmse-courses/cmse202-supplemental-data/refs/heads/main/images/knock_knock.png">

# %%
## Do not edit this
import pandas as pd

jokes = [
    {
        "p1_setup": "Knock, knock.",
        "p2_response": "Who’s there?",
        "p1_setup2": "Lettuce.",
        "p2_response2": "Lettuce who?",
        "p1_punchline": "Lettuce in, it’s cold out here!"
    },
    {
        "p1_setup": "Knock, knock.",
        "p2_response": "Who’s there?",
        "p1_setup2": "Cow says.",
        "p2_response2": "Cow says who?",
        "p1_punchline": "No, cow says moo!"
    },
    {
        "p1_setup": "Knock, knock.",
        "p2_response": "Who’s there?",
        "p1_setup2": "Etch.",
        "p2_response2": "Etch who?",
        "p1_punchline": "Bless you!"
    },
    {
        "p1_setup": "Knock, knock.",
        "p2_response": "Who’s there?",
        "p1_setup2": "Tank.",
        "p2_response2": "Tank who?",
        "p1_punchline": "You’re welcome!"
    },
    {
        "p1_setup": "Knock, knock.",
        "p2_response": "Who’s there?",
        "p1_setup2": "Orange.",
        "p2_response2": "Orange who?",
        "p1_punchline": "Orange you glad I didn’t say banana?"
    },
]
jokes_df = pd.DataFrame(jokes)

# %%
# Put your code for Question 3.3 here

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 4: Writing a Python class (18 points)

# %% [markdown]
# &#9989; **Question 4.1 (9 points)**: The following cell contains a draft of a class called `ChessPiece` with only the `__init__` constructor. Complete the `__init__` constructor so that it:
#
# - takes in three potential arguments (in addition to the argument that all methods have in python):
#   -  `color`, `shape`, with no default values. These arguments correspond to two attributes inside the init function with the same names that you need to set.
#
#   - `position`, which also needs to be set as an attribute in the init function. This should have a default value that is used if no value is given, this should be a `tuple` set to `('a', 0)`. _Note:_ `'a'` is a `str` while `0` is an `int`.
#
# - In the init function check whether `shape` is contained in the `list` `["bishop", "king", "knight", "pawn", "queen", "rook"]`. If no, print a statement that the `"Piece does not exist."` if true, set the value of the `shape` attribute inside the init function to the `shape` passed in the arguments.

# %%
# Put your code here
class ChessPiece:
    """Base class for chess pieces. 
    
    Attributes
    ----------
    color : str
        Color of the chess piece. (Such as "white" or "black")
    
    shape : str
        Shape of the chess piece. It can be only one of the following
        ["bishop", "king", "knight", "pawn", "queen", "rook"]
    
    position : tuple
        Position on the chess board.
    
    """
    def __init__(self,color,shape,position=('a',0)):
        self.color=color
        self.shape=shape
        self.position=position
        if shape not in ["bishop", "king", "knight", "pawn", "queen", "rook"]:
            print("Piece does not exist.")
        else:
            self.shape=shape
    
    def move_piece(self,new_position):
        self.position=new_position
        print("the",self.color ,self.shape,'was moved to', self.position)
        """Initialize the chess piece with its attributes color and shape 
        and set the initial position to the lower left corner of the board.
        
        Input Parameter
        ---------------
        color : str
            Color of the chess piece.
    
        shape : str
            Shape of the chess piece. It can be only one of the following
            ["bishop", "king", "knight", "pawn", "queen", "rook"]

        position : tuple
            Position on the chess board. (Default is ('a', 0))
                
        # Put your code here
        
        pass """

# %% [markdown]
# #### Test your code
#
# Let's check that the code works. Run the following cells.

# %%
#
pawn = ChessPiece(color = "white", shape = "pawn", position = ('b', 2))

pawn.position
# Out:
# ('b', 2)

# %%
# Let's try breaking the code, this should print "Piece does not exist"

archer = ChessPiece(color = "black", shape = "archer")
# Out:
# Piece does not exist.

# %% [markdown]
# &#9989; **Question 4.2 (4 point)**. Add a method to the `ChessPiece` class called `move_piece` that takes in a new position as an argument and updates the `position` attribute of the chess piece to the new position. The method should also print out a statement that says `"The [color] [shape] has moved to [new position]."` where `[color]`, `[shape]`, and `[new position]` are replaced with the appropriate values for the chess piece.

# %%
    def move_piece(self,new_position):
        self.position=new_position
        print("the",self.color ,self.shape,'was moved to', self.position)

# %% [markdown]
# &#9989; **Question 4.3 (1 point)**. Test your new `move_piece` method by moving a pawn to a new position.

# %%
# Put your code here
pawn.move_piece(('a',1))
# Out:
# the white pawn was moved to ('a', 1)

# %% [markdown]
# The following code provides a working class for how you might model different chess pieces with a class that inherits from the `ChessPiece` class.

# %%
class Queen(ChessPiece): # inherit from the ChessPiece class
    """
    Queen chess piece. Can move in any direction. It inherits the ChessPiece class.
    """
    def __init__(self, color): 
        """
        Initialize the chess piece with its attributes color and shape 
        and set the initial position to the lower left corner of the board.
        
        Input Parameter
        ---------------
        color : str
            Color of the chess piece.

        """
        self.shape = 'queen'  
        
        super().__init__(color, shape='queen') 
        
        # allowed starting positions for the queen
        if self.color == "white":     
            self.position = ("d",1)   
        elif self.color == "black": 
            self.position = ("d", 8)      

    def move_queen(self, new_position):
        """
        Move the queen to a new position.
        
        Input Parameter
        ---------------
        new_position : tuple
            The new position to move the queen to.
        """
        if self.check_if_allowable_move(new_position):
            self.position = new_position
            print(f"A {self.shape} has moved to {new_position}.")
        else:
            print(f"The move to {new_position} is not allowed.")

    def check_if_allowable_move(self, to_position):   
        """
        check if the move is allowable for a queen. A queen can move in any direction, but it cannot move to a position that is not on the chess board.
        
        Input parameter
        ---------------
        to_position: tuple
            Chess board coordinates where to move the piece.
        
        Raises
        ------
        ValueError
            For when the elements of the tuple are not part of the chess board.
        
        TypeError
            For when the input argument is not of the required type.   
        """

        # This is a simplification of the rules of chess, we are only checking if the move is on the board and not if there are other pieces in the way or if the move is legal for a queen.
        if isinstance(to_position, tuple):  
            if to_position[0] in ["a","b","c","d","e","f","g","h"] and to_position[1] in range(1,9):  # 3 point here
                return True 
            else:
                return False
        else:
            raise TypeError("Please pass a tuple.")

# %% [markdown]
# &#9989; **Question 4.4 (4 point)**. Using the code above, create two instances (objects) of the `Queen` class, one with the color white and one with the color black. Once created, move each queen to a new position and observe the output.

# %%
# Put your code here
b_Queen=Queen(color='black')
w_Queen=Queen(color='white')
b_Queen.move_queen(('d',8))
w_Queen.move_queen(('c',8))
# Out:
# A queen has moved to ('d', 8).
# A queen has moved to ('c', 8).

# %% [markdown]
# &#9989; **Question 4.5 (3 point)**. In your own words, explain how you would model a chess board in python.  How would you contruct the code to include a board with multiple different chest pieces.  What attributes and potential methods would you needed?  Is this problem best suited to be solved with linear code, functions, or classes?  Why? (Note: your answer will be assessed on how you would design your code, not on how well you understand chess.)

# %% [markdown]
# **<font size=+3>&#9998;</font> Do This**: *Record your answer here.*
# I would use classes. I think we would need to create unique objects for each shape, because they all move in unique ways. You would have to create methods for all their unique movements, and also a way to change the pawn into a queen if it reaches the end of the board. You would need to take all the same attributes above such as shape and color. You would also need to add a method if a shape kills another shape and remove it off the board. You would need to find a way to create a check using a method that finds the space of the king and an attacking piece so that you cant move unless it protects the king. You would need to find a way to cause a checkmate using a method, so that you cannot move and someone is declared the winner. You could also add in a method to see how many dead pieces you have, and the same for your opponent. Also the ability to see where everything is on the board with a method would be very helpful.

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## You're done! Congrats on finishing your CMSE 202 Midterm!
#
# Make sure all of your changes to your repository are committed and pushed to GitHub. Also upload a copy of this notebook to the dropbox on D2L in case something went wrong with your repository or if you couldn't get the repository to work.
